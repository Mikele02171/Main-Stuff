# %%
# %sql
SELECT * FROM course_training_catalog.bronze.orders LIMIT 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT 'orders' AS table_name, COUNT(*) as row_cnt FROM course_training_catalog.bronze.orders UNION ALL
SELECT 'order_items', COUNT(*) FROM course_training_catalog.bronze.order_items;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>table_name</th><th>row_cnt</th></tr></thead><tbody><tr><td>orders</td><td>99441</td></tr><tr><td>order_items</td><td>112650</td></tr></tbody></table></div>

# %%
# PySpark
df = spark.table("course_training_catalog.bronze.order_items")
display(df.select("price","freight_value").summary("count","mean","min","max"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>price</th><th>freight_value</th></tr></thead><tbody><tr><td>count</td><td>112650</td><td>112650</td></tr><tr><td>mean</td><td>120.65373901477311</td><td>19.99031992898562</td></tr><tr><td>min</td><td>0.85</td><td>0.0</td></tr><tr><td>max</td><td>6735.0</td><td>409.68</td></tr></tbody></table></div>
