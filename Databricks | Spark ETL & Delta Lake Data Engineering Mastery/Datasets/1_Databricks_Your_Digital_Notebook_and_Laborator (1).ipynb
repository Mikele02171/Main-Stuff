# %% [markdown]
# # Databricks Your Digital Notebook and Laboratory

# %%
print("Demonstration Purposes")
# Out:
# Demonstration Purposes

# %% [markdown]
# ## Shortcuts
# Select cell d twice below, exercise
# If successful, you can add in the cell manually.

# %% [markdown]
# # H1 Header
# ## H2 Header
# ### H3 Header

# %% [markdown]
# ## For example;
# - 1
# - 2

# %%
x = 7
y = 10
print(x)
print(y)
# Out:
# 7
# 10

# %%
# %sql
CREATE OR REPLACE TEMP VIEW students AS 
SELECT 1 AS id, "Alice" AS name
UNION ALL
SELECT 2, "Bob"
UNION ALL
SELECT 3, "Charlie";

SELECT * FROM students;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th></tr></thead><tbody><tr><td>1</td><td>Alice</td></tr><tr><td>2</td><td>Bob</td></tr><tr><td>3</td><td>Charlie</td></tr></tbody></table></div>

# %% [markdown]
# ### run in Genie, ask "Can you import core data science libraries?"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
