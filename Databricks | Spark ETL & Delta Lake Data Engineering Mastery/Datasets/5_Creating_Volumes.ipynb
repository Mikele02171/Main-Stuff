# %%
# %sql
-- use backticks not single quotes
SELECT * FROM csv.`/Volumes/course_training_catalog/bronze/olist_volumes/orders/olist_orders_dataset.csv`
LIMIT 10;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT COUNT(*) AS total_orders FROM csv.`/Volumes/course_training_catalog/bronze/olist_volumes/orders/olist_orders_dataset.csv`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>total_orders</th></tr></thead><tbody><tr><td>99442</td></tr></tbody></table></div>

# %%
# %fs ls /Volumes/course_training_catalog/bronze/olist_volumes
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
path = "/Volumes/course_training_catalog/bronze/olist_volumes/images/schema.png"

img = Image.open(path)
plt.figure(figsize=(20,20))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
from PIL import Image
import matplotlib.pyplot as plt
path = "/Volumes/course_training_catalog/bronze/olist_volumes/images/database.png"

img = Image.open(path)
plt.figure(figsize=(20,20))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
# %sql
-- Running all the paths of the csv files in the directory
SELECT * FROM binaryFile.`/Volumes/course_training_catalog/bronze/olist_volumes/images/*.png`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>modificationTime</th><th>length</th><th>content</th></tr></thead><tbody><tr><td>dbfs:/Volumes/course_training_catalog/bronze/olist_volumes/images/database.png</td><td>2026-03-29T08:13:24.000Z</td><td>288186</td><td>...</td></tr><tr><td>dbfs:/Volumes/course_training_catalog/bronze/olist_volumes/images/schema.png</td><td>2026-03-29T08:13:23.000Z</td><td>119788</td><td>...</td></tr></tbody></table></div>
